# %%
import pandas as pd

# %%
dataframe = pd.read_csv("./demo_data_og.csv")

# %%
dataframe
# Out:
#                Name                          Place           ID
# 0   Smith, Jennifer    New York City, Maple Street  123.456.789
# 1  Johnson, Michael             London, Elm Street  987.654.321
# 2   Williams, Emily              Paris, Oak Avenue  234.567.890
# 3    Brown, Matthew     Tokyo, Cherry Blossom Lane  567.890.123
# 4   Jones, Samantha             Sydney, Beach Road  321.654.987
# 5   Davis, Benjamin            Berlin, Main Street  890.123.456
# 6    Miller, Olivia                Rome, Via Appia  456.789.012
# 7     Wilson, Ethan  Los Angeles, Sunset Boulevard  789.012.345
# 8     Anderson, Ava          Mumbai, Market Street  012.345.678
# 9   Thomas, William          Toronto, Queen Street  678.901.234

# %%
dataframe[['First Name', 'Last Name']] = dataframe['Name'].str.split(',', expand=True)

# %%
dataframe.head()
# Out:
#   First Name  Last Name                        Place           ID
# 0      Smith   Jennifer  New York City, Maple Street  123.456.789
# 1    Johnson    Michael           London, Elm Street  987.654.321
# 2   Williams      Emily            Paris, Oak Avenue  234.567.890
# 3      Brown    Matthew   Tokyo, Cherry Blossom Lane  567.890.123
# 4      Jones   Samantha           Sydney, Beach Road  321.654.987

# %%
dataframe.drop('Name', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 dataframe.drop('Name', axis=1, inplace=True)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# ...

# %%
dataframe.head()
# Out:
#   First Name  Last Name                        Place           ID
# 0      Smith   Jennifer  New York City, Maple Street  123.456.789
# 1    Johnson    Michael           London, Elm Street  987.654.321
# 2   Williams      Emily            Paris, Oak Avenue  234.567.890
# 3      Brown    Matthew   Tokyo, Cherry Blossom Lane  567.890.123
# 4      Jones   Samantha           Sydney, Beach Road  321.654.987

# %%
dataframe = dataframe[['First Name', 'Last Name', 'Place', 'ID']]

# %%
dataframe.head()
# Out:
#   First Name  Last Name                        Place           ID
# 0      Smith   Jennifer  New York City, Maple Street  123.456.789
# 1    Johnson    Michael           London, Elm Street  987.654.321
# 2   Williams      Emily            Paris, Oak Avenue  234.567.890
# 3      Brown    Matthew   Tokyo, Cherry Blossom Lane  567.890.123
# 4      Jones   Samantha           Sydney, Beach Road  321.654.987

# %%
dataframe.reindex(columns=['First Name', 'Last Name', 'Place', 'ID'])
# Out:
#   First Name  Last Name                          Place           ID
# 0      Smith   Jennifer    New York City, Maple Street  123.456.789
# 1    Johnson    Michael             London, Elm Street  987.654.321
# 2   Williams      Emily              Paris, Oak Avenue  234.567.890
# 3      Brown    Matthew     Tokyo, Cherry Blossom Lane  567.890.123
# 4      Jones   Samantha             Sydney, Beach Road  321.654.987
# 5      Davis   Benjamin            Berlin, Main Street  890.123.456
# 6     Miller     Olivia                Rome, Via Appia  456.789.012
# 7     Wilson      Ethan  Los Angeles, Sunset Boulevard  789.012.345
# 8   Anderson        Ava          Mumbai, Market Street  012.345.678
# 9     Thomas    William          Toronto, Queen Street  678.901.234

# %%
import openai

openai.api_key = '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'

# response = openai.Completion.create(
#   engine="text-davinci-003",
#   prompt="What dinosaurs lived in the cretaceous period?",
#   max_tokens=60
# )

# %%
# response.choices[0].text.strip()

# %%
dataframe.columns.tolist()
# Out:
# ['First Name', 'Last Name', 'Place', 'ID']

# %%
"""
    #     Only output python3. Do not write any text to explain. 
    #     I should be directly able to execute your output on my computer using python's exec method, so make sure it is safe. 
    #     Below, I provide the Columns of data and user's prompt. 
    #     Convert that prompt to pandas code. Call the dataframe variable object "dataframe". 
    #     Do not write any imports, use libraries other than pandas and numpy, or define the dataframe variable.

    #     Columns: {}
    #     Prompt: {}
    #     """.format(dataframe.columns.tolist(), "hi")
# Out:
# '\n    #     Only output python3. Do not write any text to explain. \n    #     I should be directly able to execute your output on my computer using python\'s exec method, so make sure it is safe. \n    #     Below, I provide the Columns of data and user\'s prompt. \n    #     Convert that prompt to pandas code. Call the dataframe variable object "dataframe". \n    #     Do not write any imports, use libraries other than pandas and numpy, or define the dataframe variable.\n\n    #     Columns: [\'First Name\', \'Last Name\', \'Place\', \'ID\']\n    #     Prompt: hi\n    #     '

# %%
dataframe.reindex(columns=['Last Name', 'First Name', 'Place', 'ID'])
# Out:
#    Last Name First Name                          Place           ID
# 0   Jennifer      Smith    New York City, Maple Street  123.456.789
# 1    Michael    Johnson             London, Elm Street  987.654.321
# 2      Emily   Williams              Paris, Oak Avenue  234.567.890
# 3    Matthew      Brown     Tokyo, Cherry Blossom Lane  567.890.123
# 4   Samantha      Jones             Sydney, Beach Road  321.654.987
# 5   Benjamin      Davis            Berlin, Main Street  890.123.456
# 6     Olivia     Miller                Rome, Via Appia  456.789.012
# 7      Ethan     Wilson  Los Angeles, Sunset Boulevard  789.012.345
# 8        Ava   Anderson          Mumbai, Market Street  012.345.678
# 9    William     Thomas          Toronto, Queen Street  678.901.234

# %%
dataframe.reindex(columns=['Last Name', 'First Name', 'Place', 'ID'], copy=False)
# Out:
#    Last Name First Name                          Place           ID
# 0   Jennifer      Smith    New York City, Maple Street  123.456.789
# 1    Michael    Johnson             London, Elm Street  987.654.321
# 2      Emily   Williams              Paris, Oak Avenue  234.567.890
# 3    Matthew      Brown     Tokyo, Cherry Blossom Lane  567.890.123
# 4   Samantha      Jones             Sydney, Beach Road  321.654.987
# 5   Benjamin      Davis            Berlin, Main Street  890.123.456
# 6     Olivia     Miller                Rome, Via Appia  456.789.012
# 7      Ethan     Wilson  Los Angeles, Sunset Boulevard  789.012.345
# 8        Ava   Anderson          Mumbai, Market Street  012.345.678
# 9    William     Thomas          Toronto, Queen Street  678.901.234

# %%
dataframe
# Out:
#   First Name  Last Name                          Place           ID
# 0      Smith   Jennifer    New York City, Maple Street  123.456.789
# 1    Johnson    Michael             London, Elm Street  987.654.321
# 2   Williams      Emily              Paris, Oak Avenue  234.567.890
# 3      Brown    Matthew     Tokyo, Cherry Blossom Lane  567.890.123
# 4      Jones   Samantha             Sydney, Beach Road  321.654.987
# 5      Davis   Benjamin            Berlin, Main Street  890.123.456
# 6     Miller     Olivia                Rome, Via Appia  456.789.012
# 7     Wilson      Ethan  Los Angeles, Sunset Boulevard  789.012.345
# 8   Anderson        Ava          Mumbai, Market Street  012.345.678
# 9     Thomas    William          Toronto, Queen Street  678.901.234
